# %%
from sklearn import datasets
import numpy as np

iris = datasets.load_iris()
X = iris.data[:, [2,3]]
y = iris.target
print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
print('Labels count in y      :', np.bincount(y))
print('Labels count in y_train:', np.bincount(y_train))
print('Labels count in y_test :', np.bincount(y_test))
# Out:
# Labels count in y      : [50 50 50]
# Labels count in y_train: [35 35 35]
# Labels count in y_test : [15 15 15]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train_std, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=0.1,
#            fit_intercept=True, max_iter=40, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=1, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = ppn.predict(X_test_std)
print('Misclassified samples :', (y_test != y_pred).sum())
print('Accuracy              :', ((y_test == y_pred).sum()/len(y_test)))
# Out:
# Misclassified samples : 1
# Accuracy              : 0.9777777777777777

# %%
from sklearn.metrics import accuracy_score

print('Accuracy              :', accuracy_score(y_test, y_pred))
# Out:
# Accuracy              : 0.9777777777777777

# %%
print('Accuracy              :', ppn.score(X_test_std, y_test))
# Out:
# Accuracy              : 0.9777777777777777

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    
    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    
    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution), np.arange(x2_min, x2_max, resolution))
    z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    z = z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, z, alpha=0.2, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1], alpha=0.8, c=colors[idx], marker=markers[idx], label=cl, edgecolor='black')
        
    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]
        
        plt.scatter(X_test[:, 0], X_test[:, 1], c='', alpha=1.0, marker='o', s=100, label='test set', linewidth=1, edgecolor='black')

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X=X_combined_std, y=y_combined, classifier=ppn, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')

# %%
def sigmoid(z):
    return 1.0 / (1.0 + np.exp(-z))

z = np.arange(-7, 7, 0.1)
phi_z = sigmoid(z)
plt.plot(z, phi_z)
plt.axvline(0.0, color='k')
plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$')
plt.yticks([0.0, 0.5, 1.0])
ax = plt.gca()
ax.yaxis.grid(True)

# %%
from logistic_regression_gd import LogisticRegressionGD

X_train_01_subset = X_train[(y_train == 0) | (y_train == 1)]
y_train_01_subset = y_train[(y_train == 0) | (y_train == 1)]
lrgd = LogisticRegressionGD(eta=0.05, n_iter=1000, random_state=1).fit(X_train_01_subset, y_train_01_subset)
plot_decision_regions(X=X_train_01_subset, y=y_train_01_subset, classifier=lrgd)
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
# Out:
# Text(0, 0.5, 'petal width [standardized]')

# %%
plt.plot(range(1, len(lrgd.cost_) + 1), lrgd.cost_, marker='o')

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=100.0, random_state=1, solver='lbfgs', multi_class='ovr').fit(X_train_std, y_train)
plot_decision_regions(X_combined_std, y_combined, classifier=lr, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')

# %%
weights, params = [], []
for c in np.arange(-5, 5):
    lr = LogisticRegression(C=10.0**c, random_state=1, solver='lbfgs', multi_class='ovr').fit(X_train_std, y_train)
    weights.append(lr.coef_[1])
    params.append(10.0**c)
weights = np.array(weights)
plt.plot(params, weights[:, 0], label='petal length')
plt.plot(params, weights[:, 1], label='petal width')
plt.ylabel('weight coefficient')
plt.xlabel('C')
plt.legend(loc='upper left')
plt.xscale('log')

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', C=1.0, random_state=1).fit(X_train_std, y_train)
plot_decision_regions(X_combined_std, y_combined, classifier=svm, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')

# %%
np.random.seed(1)
X_xor = np.random.randn(400, 2)
Y_xor = np.logical_xor(X_xor[:, 0] > 0, X_xor[:, 1] > 0)
Y_xor = np.where(Y_xor, 1, 0)
plt.scatter(X_xor[Y_xor == 1, 0], X_xor[Y_xor == 1, 1], c='b', marker='x', label='1')
plt.scatter(X_xor[Y_xor == 0, 0], X_xor[Y_xor == 0, 1], c='r', marker='s', label='-1')

# %%
svm = SVC(kernel='rbf', random_state=1, gamma=0.1, C=10.0).fit(X_xor, Y_xor)
plot_decision_regions(X_xor, Y_xor, classifier=svm)

# %%
from logistic_regression_gd import LogisticRegressionGD

X_xor = np.concatenate((X_xor[:,0].reshape(-1, 1), X_xor[:,1].reshape(-1, 1), (X_xor[:,0] * X_xor[:,1]).reshape(-1, 1)), axis=1)
    
def plot(min, max, X, Y, classifier, res=0.01):
    
    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ['red', 'blue', 'lightgreen', 'gray', 'cyan']
    cmap = ListedColormap(colors[len(np.unique(Y))-1::-1])
    
    cords = []
    for x in np.arange(max, min - res, -res):
        for y in np.arange(min, max + res, res):
            cords.append([x, y, x*y])
    cords = np.array(cords)
    plt.contourf(np.arange(min, max + res, res), np.arange(min, max + res, res), classifier.predict(cords).reshape(int(1 + (max - min) / res), int(1 + (max - min) / res)), alpha=0.2, cmap=cmap)
    plt.xlim(min, max)
    plt.ylim(min, max)
    
    for i in range(len(np.unique(Y))):
        plt.scatter(x=X[Y == i, 0], y=X[Y == i, 1], alpha=0.8, c=colors[i], marker=markers[i], label=i, edgecolor='black')

plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=0).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=1).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=2).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=3).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=4).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=5).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=15).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegressionGD(eta=0.005, n_iter=50).fit(X_xor, Y_xor))

# %%
plot(-3, 3, X_xor, Y_xor, LogisticRegression(solver='lbfgs').fit(X_xor, Y_xor))

# %%
from adaline_gd import AdalineGD

lr = AdalineGD(eta=0.003, n_iter=25).fit(X_xor, Y_xor)

plt.plot(range(1, len(lr.cost_) + 1), lr.cost_, marker='o')
